# %% [markdown]
# <table style="width:100%; background-color:#FFFFFF" align="left">
# <tr>
#     <td style="text-align:left; background-color:#FFFFFF">
#        <p>Prof. Dr. Stefan Decker <br>
#         M. Slupczynski <br>
#         L. Neumann <br>
#         M. Kißgen <br>
#         T. Holzheim</p>
#         <p><strong>20-06-2025</strong></p>
#     </td>
#     <td style="text-align:right; background-color:#FFFFFF">
#         <div>
#         <img src="https://git.rwth-aachen.de/i5/teaching/dbis-raw/-/raw/main/dbis-logo.png" width="500"/>
#         </div>
#     </td>
# </tr>
# </table>
# <div class="clearfix"></div>
# <center>
#     <h1>Datenbanken und Informationssysteme (SoSe 2025) </h1>
#     <h1>Übung 9 - MongoDB</h1>
# </center>
#
# <center>
#     <h4>Abgabe bis 27-06-2025 14:15 Uhr</h4>
#     <strong>Zu spät eingereichte Übungen werden nicht berücksichtigt.</strong>
# </center>

# %% [markdown]
# <div class="hidden-print"><hr />
# <h3> Wichtige Hinweise</h3>
# <ul>
# <li>Bei Nichtbeachtung dieser Hinweise wird die Abgabe mit 0 Punkten bewertet!</li>
# <li>Bitte laden Sie Ihre digitalen Lösungen mit diesem Notebook ins Moodle hoch.</li>
# <li>Bitte geben Sie Namen, Matrikelnummern auf der schriftlichen Lösung an.</li>
# </ul></div>
#
# <strong>Die Lösung zu diesem Übungsblatt wird in den Übungen am 27. und 30. Juni vorgestellt. <br />
# Bitte beachten Sie auch die aktuellen Ankündigungen im Moodle-Lernraum zur Vorlesung. </strong> <br />
# <em>* bezeichnet Bonusaufgaben.</em>
# <hr />

# %% [markdown]
# <h3>Dokumentations-Notebook</h3>
#
# Wir empfehlen ihnen das zu dieser Übung zugehörige Dokumentations-Notebook zu lesen. Zusätzlich zur der Handhabung der verschiedenen verwendeten Tools werden dort zentrale Konzepte der Vorlesung noch einmal wiederholt. Sie finden das Notebook im <a href="https://moodle.rwth-aachen.de/course/view.php?id=48593">Moodle Lernraum</a>.

# %% [markdown]
# <h3>Abgabegruppe</h3>
# Es ist möglich die Abgabe in Gruppen von bis zu fünf Personen zu bearbeiten. <strong>Jeder Gruppenteilnehmer muss für sich ein Notebook hochladen</strong>. Wenn Sie in einer Abgabegruppe arbeiten, dürfen die Notebooks der Gruppenteilnehmer den gleichen Inhalt aufweisen. Wenn Sie in einer Gruppe arbeiten, tragen Sie hier bitte alle Gruppenteilnehmer inklusive sich selbst ein. <strong>Eine inkonsistente Angabe von Gruppenmitgliedern bei den Teilnehmern führt im Zweifel zu 0 Punkten für alle Gruppenteilnehmer!</strong> Es ist möglich zwischen den Abgaben die Gruppen zu wechseln.

# %% [markdown]
# <h4>Andere Gruppenteilnehmer (Wenn Einzelabgabe, bitte leer lassen)</h4>
# <ul>
#     <li>Neo Ahrens, 456647</li>
#     <li>Yorck Heilmann, 456599</li>
#     <li>Christian Bick, 456513</li>
#     <li>Michael Hübner, 457202</li>
#     <li>Kai Seeling, 456990</li>
# </ul>

# %% [markdown]
# <div class="alert alert-info hidden-print">Die folgende Codezelle sollte zu Beginn der Bearbeitung der Übung ausgeführt werden. <br /> Am Ende sollte <b>"OK, es kann los gehen!"</b> stehen. Dies kann ein paar Minuten dauern.</div>
# <div class="alert alert-danger">
#     Sie sollten die weiteren Zellen erst ausführen, wenn <b>"OK, es kann los gehen!"</b> am Ende der Ausgabe der nächsten Zelle steht. <br /> Andere Ausgaben dieser Zelle können ignoriert werden. <br />
# </div>

# %%
# install the functional dependencies library
# !python --version
# %pip install -q "dbis-exc-manager~=1.0.2" "bson"
from IPython.display import display, HTML
import warnings
try:
    # import libraries
    from excmanager.Task import Exercise, Task, SubTask
    # initialize task structure
    exc = Exercise(9)
    task1 = Task(exc, "9.1")
    task2 = Task(exc, "9.2")
    task3 = Task(exc, "9.3")
    task4 = Task(exc, "9.4")
    task5 = Task(exc, "9.5")
    tasks_ready = {"9.1": {}, "9.2": {}, "9.3": {}, "9.4": {}, "9.5": {}}
except Exception as e:
    display(HTML(
        f"<div class='alert alert-danger'><h2>Etwas ist beim import schief gelaufen:</h1>{e}</div>"))
    raise e
else:
    display(
        HTML("<div class='alert alert-success'><h1>OK, es kann los gehen!</h1></div>"))
# Out:
# Python 3.13.3
# Note: you may need to restart the kernel to use updated packages.
# <div class='alert alert-success'><h1>OK, es kann los gehen!</h1></div>

# %% [markdown]
# <div class="pull-left">
#     <h2> Aufgabe 9.1 (Grundlagen, MQL) </h2>
# </div>
#
# <div class="pull-right">
#     <h3> (2 Punkte) </h3>
# </div>

# %% [markdown]
# Für die folgenden Aufgaben sollen Sie Multiple Choice Fragen zu Grundlagen der MongoDB beantworten. Bitte wählen Sie immer **alle** korrekten Möglichkeiten aus.

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.1 a)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Welche der Aussagen über MongoDB sind richtig? Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Wegen der dokumentenbasierten Struktur und des flexiblen Schemas erzielt MongoDB eine bessere ACID-Konformität als relationale Datenbanken.<br>
# b. Da Dokumente in derselben Collection unterschiedliche Felder und Datentypen haben können, ist die Skalierung sehr schwierig.<br>
# c. Zu dem Datenmodell, welches in der VL präsnetiert wurde: Ein `Professor`-Objekt aus der Professor-Collection kann bis zu 2 `Vorlesung`-Objekte und beliebig viele `Student`-Objekte enthalten. Zur Darstellung beider Beziehungen ist **Referenzierung** besser geeignet als **Einbettung**.<br>
# d. Jedes Object enthält ein `_id`-Feld.<br>
# e. Es ist unmöglich, ein Dokument in MongoDB einzufügen, dessen Schema nicht definiert ist.<br>
# f. In MongoDB ist eine Collection vergleichbar mit einer Tabelle in einer relationalen Datenbank.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result = {'c','d','f'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.1 a1 mit 1 Punkten
subtask1 = SubTask(task1, "a1", points = 1)

tasks_ready[subtask1.task.task][subtask1.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask1.task.task][subtask1.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask1.task.task][subtask1.subtask] = False


# Bitte ignorieren
subtask1.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.1 b)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Gegeben sei eine Collection `tracks`:
# ```json
# [
#   {
#     _id: "t1",
#     name: "Bohemian Rhapsody",
#     genre: "Rock",
#     artist: "Queen"
#   },
#   {
#     _id: "t2",
#     name: "Shape of You",
#     genre: "Pop",
#     artist: "Ed Sheeran"
#   },
#   {
#     _id: "t3",
#     name: "Blinding Lights",
#     genre: "Synthpop",
#     artist: "The Weeknd"
#   },
#   {
#     _id: "t4",
#     name: "Sweet Child O' Mine",
#     genre: "Rock",
#     artist: "Guns N' Roses"
#   },
#   {
#     _id: "t5",
#     name: "One Of The Girls",
#     genre: "Contemporary R&B",
#     artist: "The Weeknd"
#   },
# ]
# ```

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Welche der Aussagen über die CRUD Operationen auf diese Collection sind richtig? Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. `db.tracks.find()` liefert 0 Dokumente als Ergebnis.<br>
# b. `db.tracks.find({genre: "Rock"})` liefert 2 Dokumente als Ergebnis.<br>
# c. Die Abfrage `db.tracks.deleteOne({"artist": "The Weeknd"})` entfernt beide Tracks des Künstlers "The Weeknd".<br>
# d. Die Operation `db.tracks.insertOne({"_id": "t2", "name": "Perfect", "genre": "Pop", "artist": "Ed Sheeran"})` überschreibt das bestehende Dokument von "Shape of You".<br>
# e. Die Operation `db.tracks.updateOne({"_id": "t1"}, {"$unset": {"genre": ""}})` entfernt das genre-Feld aus dem Dokument von "Bohemian Rhapsody".<br>
# f. Die Operation `db.tracks.insertMany([{"_id": "t6", "name": "Thriller", "genre": "Pop", "artist": "Michael Jackson"}, {"_id": "t2", "name": "Perfect", "genre": "Pop", "artist": "Ed Sheeran"}])` fügt beide Dokumente erfolgreich ein.<br>
# g. Die Operation `db.tracks.insertOne({"name": "Perfect", "genre": "Pop", "artist": "Ed Sheeran"})` fügt ein Dokument erfolgreich ein.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'b','e','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.1 b1 mit 1 Punkten
subtask1 = SubTask(task1, "b1", points = 1)

tasks_ready[subtask1.task.task][subtask1.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask1.task.task][subtask1.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask1.task.task][subtask1.subtask] = False


# Bitte ignorieren
subtask1.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h2> Aufgabe 9.2 (Datenmodellierung) </h2>
# </div>
#
# <div class="pull-right">
#     <h3> (6 Punkte) </h3>
# </div>

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.2 a)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wann werden Daten typischerweise eingebettet? Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Wenn zusammengehörige Daten häufig gemeinsam gelesen werden.<br>
# b. Wenn zwischen zwei Entitäten eine viele-zu-viele-Beziehung besteht.<br>
# c. Wenn zusammengehörige Informationen möglichst atomar in einem Schritt gespeichert und verändert werden sollen.<br>
# d. Wenn eine untergeordnete Datenmenge potenziell sehr groß und unbegrenzt wachsend ist.<br>
# e. Wenn einzelne Teile der eingebetteten Informationen regelmäßig unabhängig voneinander aktualisiert werden.<br>
# f. Wenn es wichtig ist, die Wiederholung identischer Informationen in mehreren Datensätzen zu vermeiden.<br>
# g. Wenn es sich um eine überschaubare Eins-zu-Wenige-Beziehung handelt und die Daten logisch stark verbunden sind.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','c','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.2 a1 mit 1 Punkten
subtask2 = SubTask(task2, "a1", points = 1)

tasks_ready[subtask2.task.task][subtask2.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False


# Bitte ignorieren
subtask2.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.2 b)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wann werden Daten typischerweise referenziert? Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Wenn bestimmte Informationen mehrfach in verschiedenen Datensätzen verwendet werden und bei Änderungen konsistent bleiben sollen.<br>
# b. Wenn zusammengehörige Daten immer gemeinsam gelesen werden und sich selten ändern.<br>
# c. Wenn untergeordnete Daten potenziell sehr umfangreich sind oder stark anwachsen können.<br>
# d. Wenn es wichtig ist, atomare Operationen auf alle Teile einer komplexen Datenstruktur durchzuführen.<br>
# e. Wenn es sich um eine viele-zu-viele-Beziehung zwischen zwei Entitätstypen handelt.<br>
# f. Wenn unterschiedliche Teile eines Datensatzes unabhängig voneinander häufig aktualisiert werden.<br>
# g. Wenn die maximale Größe einzelner Dokumente nicht überschritten werden darf.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','c','e','f','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.2 b1 mit 1 Punkten
subtask2 = SubTask(task2, "b1", points = 1)

tasks_ready[subtask2.task.task][subtask2.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False


# Bitte ignorieren
subtask2.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.2 c)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(2 Punkt)</h4>
#
# </div>

# %% [markdown]
# Im Folgenden betrachten wir ein Datenmodell für Playlists und Lieder in einer Musikdatenbank:
# <pre>
# {
#     "Playlistname": "Rock-Playlist",
#     "Ersteller": "Linus",
#     "Erstelldatum": "11.04.2025",
#     "gespeichert": [
#         {"Nutzername": "Linus"},
#         {"Nutzername": "Anna"}
#     ],
#     "Lieder": [
#         {"lied_id_ref": ObjectId("lied1")},
#         {"lied_id_ref": ObjectId("lied2")},
#     ]
# }
# {
#     "lied_id_ref": ObjectId("lied1"),
#     "Titel": "How You Remind Me",
#     "Künstler": "Nickelback"
#  }
# {
#     "lied_id_ref": ObjectId("lied2"),
#     "Titel": "Rockstar",
#     "Künstler": "Nickelback"
#  }
#  </pre>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Wenn mehr Informationen über die Künstler hinzugefügt werden, und diese Häufig abgefragt werden ist es effizienter die Künstler zu referenzieren und nicht mehr direkt in die Lieder einzubetten.<br>
# b. Es gibt eine effiziente Abfrage um herauszufinden welche Playlists ein Nutzer gespeichert hat.<br>
# c. Obiges Datenmodell kann durch Referenzierung nicht verbessert werden.<br>
# d. Wenn die häufigste Abfrage ist, welche Nutzer eine bestimmte Playlist gespeichert haben ist obiges Datenmodell optimal.<br>
# e. Im Datenmodell wird sowohl Einbettung als auch Referenzierung verwendet.<br>
# f. Es kann zu Problemen kommen, wenn zu einer Playlist im obigen Datenmodell eine sehr große Anzahl an Liedern hinzugefügt wird.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','d','e','f'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.2 c1 mit 2 Punkten
subtask2 = SubTask(task2, "c1", points = 2)

tasks_ready[subtask2.task.task][subtask2.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False


# Bitte ignorieren
subtask2.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.2 d)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(2 Punkt)</h4>
#
# </div>

# %% [markdown]
# <pre>
# 1.  {"_id": "v1001",
#     "titel": "Theaterabend",
#     "reservierungen": [
#       { "sitzplatz": "A15",
#         "nutzer": "Mila Schulz",
#         "reserviert_am": "2025-06-01"},
#       { "sitzplatz": "B12",
#         "nutzer": "Lars König",
#         "reserviert_am": "2025-06-02"}
#       ]
#     }
#
# 2.  {"Rechnungs_id": "r123",
#     "kunde": "K123",
#     "datum": "2025-06-01",
#     "positionen": [
#       { "artikel": "Stift", "menge": 2, "preis": 1.5 },
#       { "artikel": "Heft", "menge": 3, "preis": 2.0 }
#         ]
#     }
#
# 3.  {"_id": ObjectId("SSB1"), "name": "Steven Spielberg" },
#     {"_id": ObjectId("WH1"), "titel": "Der weiße Hai", "director_id_ref": ObjectId("SSB1") }
#  </pre>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Es kann zwei unterschiedliche Nutzungsfälle geben, in denen dieselben Daten einmal referenziert und im anderen Fall eingebettet werden.<br>
# b. Für 1. wäre eine Referenzierung besser, wenn Sitzplatzreservierungen sehr häufig einzeln bearbeitet werden.<br>
# c. Für 2. ist eine Einbettung der Positionen eine gute Wahl, weil Rechnungen selten geändert werden.<br>
# d. Für 2. wäre eine Referenzierung der Positionen besser, wenn häufig die Positionen in Verbindung mit der Rechnung abgefragt werden.<br>
# e. Für 3. gibt es weniger Redundanzen, wenn eine Einbettung der Directoren vorgenommen wird.<br>
# f. Für 3. ist die dargestellte Referenzierung die effizienteste Möglichkeit, um die Abfrage durchzuführen, welcher Director zu dem Weißen Hai gehört.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','c','f'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.2 d1 mit 2 Punkten
subtask2 = SubTask(task2, "d1", points = 2)

tasks_ready[subtask2.task.task][subtask2.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask2.task.task][subtask2.subtask] = False


# Bitte ignorieren
subtask2.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h2> Aufgabe 9.3 (SQL Migration) </h2>
# </div>
#
# <div class="pull-right">
#     <h3> (2 Punkte) </h3>
# </div>

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.3 a)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. SQL-Tabellen werden häufig zu einzelnen MongoDB-Dokumenten zusammengeführt (Denormalisierung).<br>
# b. Relationale Beziehungen wie 1:1, 1:N oder N:M müssen beim Umstieg auf MongoDB explizit durch Einbetten oder Referenzieren modelliert werden.<br>
# c. SQL-Foreign-Keys werden in MongoDB automatisch als Referenzen erkannt.<br>
# d. Tabellen mit Fremdschlüsseln in SQL werden in MongoDB häufig in mehrere Collections aufgeteilt, um die Beziehungen durch Referenzen oder Einbettungen abzubilden.<br>
# e. Beim Migrieren sollte auf Einhaltung des 16MB-Limits je Dokument geachtet werden.<br>
# f. Joins werden in MongoDB beim Import automatisch in $lookup-Pipelines umgewandelt.<br>
# g. Häufig genutzte Leseabfragen beeinflussen die Modellierungsentscheidung bei der Migration.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','d','e','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.3 a1 mit 1 Punkten
subtask3 = SubTask(task3, "a1", points = 1)

tasks_ready[subtask3.task.task][subtask3.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask3.task.task][subtask3.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask3.task.task][subtask3.subtask] = False


# Bitte ignorieren
subtask3.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.3 b)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. ``SELECT * FROM users`` entspricht ``db.users.find({})``.<br>
# b. ``INSERT INTO users (...) VALUES (...);`` entspricht ``db.users.insertOne({...})``.<br>
# c. ``UPDATE users SET name = 'Bob' WHERE id = 1`` wird mit ``updateMany()`` umgesetzt.\
# d. ``DELETE FROM users WHERE active = "false"`` entspricht ``db.users.deleteMany({active: "false"})``.<br>
# e. ``REPLACE INTO ...`` wird mit ``replaceOne()`` umgesetzt.<br>
# f. ``JOIN``-basierte Queries können durch Aggregation mit ``$lookup`` umgesetzt werden.<br>
# g. In MongoDB gibt es kein direktes Äquivalent zu SQLs ``DELETE``.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','d','e','f'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.3 b1 mit 1 Punkten
subtask3 = SubTask(task3, "b1", points = 1)

tasks_ready[subtask3.task.task][subtask3.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask3.task.task][subtask3.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask3.task.task][subtask3.subtask] = False


# Bitte ignorieren
subtask3.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h2> Aufgabe 9.4 (Indizierung) </h2>
# </div>
#
# <div class="pull-right">
#     <h3> (4 Punkte) </h3>
# </div>

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.4 a)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Ein Single Field Index auf ``{field: 1}`` ist immer schneller als ein Compound Index, egal wie die Abfrage aussieht.<br>
# b. Indizes beschleunigen Leseoperationen, indem sie eine sortierte Datenstruktur mit Zeigern zu Dokumenten bereitstellen.<br>
# c. Das Anlegen eines Index auf einer großen Collection kann während der Erstellung die Performance aller Operationen beeinträchtigen.<br>
# d. Schreiboperationen wie ``insert`` oder ``update`` werden durch Indizes tendenziell verlangsamt, da die Indexstruktur angepasst werden muss.<br>
# e. Indizes sind speicherneutral und belegen keinen zusätzlichen Speicherplatz.<br>
# f. Ohne Indizes muss MongoDB immer einen Collection Scan durchführen, was bei großen Datenmengen ineffizient ist.<br>
# g. Indizes können in seltenen Fällen die Abfrageplanung negativ beeinflussen, wenn sie nicht passend zur Abfrage gestaltet sind.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'b','c','d','f','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.4 a1 mit 1 Punkten
subtask4 = SubTask(task4, "a1", points = 1)

tasks_ready[subtask4.task.task][subtask4.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False


# Bitte ignorieren
subtask4.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.4 b)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(2 Punkt)</h4>
#
# </div>

# %% [markdown]
# ```json
# // Beispiel 1
# db.getCollection("studenten_sql_final_v5").createIndex({MatrNr: 1, Name: -1}, {name: "idx_matrnr_name"});
#
# // Beispiel 2
# db.getCollection("professoren_sql_final_v5").createIndex({Rang: 1, Raum: 1}, {name: "idx_rang_raum"});
#
# // Beispiel 3
# db.getCollection("kurse_final").createIndex({Semester: 1, Note: 1}, {name: "idx_semester_note"});
# ```

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Der Index aus Beispiel 1 wird effizient genutzt bei einer Abfrage mit Filter auf ``MatrNr`` und Sortierung nach ``Name`` absteigend.<br>
# b. Der Index aus Beispiel 1 kann vollständig genutzt werden, auch wenn nur nach ``Name`` gefiltert wird.<br>
# c. Der Index aus Beispiel 2 ist optimal für eine Abfrage wie ``{ Rang: "W3" }`` mit ``.sort({Raum: 1})``.<br>
# d. Der Index aus Beispiel 3 kann für eine Abfrage mit ``{Note: {$gte: 2.0}}`` effizient verwendet werden, auch ohne Filter auf ``Semester``.<br>
# e. Die Feldreihenfolge in Compound Indizes beeinflusst sowohl die Filter- als auch die Sortierleistung.<br>
# f. Ein Compound Index auf ``{A: 1, B: 1}`` ist effizient auch für Abfragen, die ausschließlich nach ``B`` filtern.<br>
# g. Bei Compound Indizes ist die erste Feldkomponente entscheidend für die Nutzbarkeit des Index in Abfragen.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','c','e','g'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.4 b1 mit 2 Punkten
subtask4 = SubTask(task4, "b1", points = 2)

tasks_ready[subtask4.task.task][subtask4.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False


# Bitte ignorieren
subtask4.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.4 c)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# Was sind mögliche Parameter von updateOne() in MongoDB?<br>
# a. Ein Filter-Dokument zur Auswahl eines Zieldokuments.<br>
# b. Ein Update-Dokument mit Operatoren wie ``$set``.<br>
# c. Ein Aggregations-Array zur Dokumenten-Transformation.<br>
# d. Ein optionales Optionsobjekt (z. B. upsert).<br>
# e. Ein Callback-Handler für asynchrone Verarbeitung.<br>
# f. Ein Array von Dokumenten.<br>
# g. Eine ``$merge``-Definition.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','c','d','e'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.4 c1 mit 1 Punkten
subtask4 = SubTask(task4, "c1", points = 1)

tasks_ready[subtask4.task.task][subtask4.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask4.task.task][subtask4.subtask] = False


# Bitte ignorieren
subtask4.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h2> Aufgabe 9.5 (Aggregation Pipeline) </h2>
# </div>
#
# <div class="pull-right">
#     <h3> (6 Punkte) </h3>
# </div>

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.5 a)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!<br>
# Welche Aussagen zu ``$group`` sind korrekt?
#
# a. Gruppiert Dokumente nach gemeinsamem Wert.<br>
# b. Gibt alle Felder der Originaldokumente zurück.<br>
# c. Ermöglicht Aggregatfunktionen wie ``$sum``, ``$avg``.<br>
# d. Erzeugt ein neues Dokument pro Gruppierung.<br>
# e. Erfordert immer einen ``$project``-Schritt davor.<br>
# f. Kann mehrere Felder als Gruppierungsschlüssel verwenden.<br>
# g. Setzt zwingend einen Index voraus.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','c','d'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.5 a1 mit 1 Punkten
subtask5 = SubTask(task5, "a1", points = 1)

tasks_ready[subtask5.task.task][subtask5.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False


# Bitte ignorieren
subtask5.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.5 b)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(1 Punkt)</h4>
#
# </div>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!<br>
# Welche Best Practices verbessern die Performanz einer MongoDB-Datenbank?
#
# a. Relevante Felder indexieren.<br>
# b. Projektion nur notwendiger Felder verwenden.<br>
# c. Dokumente klein und flach halten.<br>
# d. ``$where`` möglichst häufig einsetzen.<br>
# e. Sharding bei sehr großen Datenmengen in Betracht ziehen.<br>
# f. Dokumente per ``$set`` vollständig ersetzen.<br>
# g. Aggregationen möglichst auf dem Client ausführen.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','b','c','e'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.5 b1 mit 1 Punkten
subtask5 = SubTask(task5, "b1", points = 1)

tasks_ready[subtask5.task.task][subtask5.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False


# Bitte ignorieren
subtask5.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.5 c)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(2 Punkt)</h4>
#
# </div>

# %% [markdown]
# Datenmodell:
# ```json
# {
#   "_id": ObjectId,
#   "customer": {
#     "id": "c102",
#     "name": "Anna Neumann",
#     "vip": true
#   },
#   "items": [
#     { "product": "Laptop", "quantity": 1, "price": 999 },
#     { "product": "Mouse", "quantity": 2, "price": 25 }
#   ],
#   "orderDate": ISODate("2023-12-10T09:00:00Z"),
#   "status": "shipped",
#   "region": "Europe"
# }
# ```

# %% [markdown]
# <pre>
# 1.  db.orders.aggregate([
#     { $unwind: "$items" },
#     { $group: {
#         _id: "$items.product",
#         totalQty: { $sum: "$items.quantity" }
#     }},
#     { $sort: { totalQty: -1 } }
#     ])
#
# 2.  db.orders.aggregate([
#     { $project: {
#         customerName: "$customer.name",
#         vipStatus: "$customer.vip",
#         firstItemName: { $arrayElemAt: ["$items.product", 0] }
#     }}
#     ])
#
# 3.  db.orders.aggregate([
#     { $sort: { orderDate: -1 } },
#     { $group: {
#         _id: "$customer.id",
#         lastOrderDate: { $first: "$orderDate" },
#         lastRegion: { $first: "$region" }
#     }}
#     ])
# </pre>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Zu 1.: Die Ausgabe zeigt alle Produkte mit ihrer aggregierten Gesamtanzahl – sortiert aufsteigend nach Menge.<br>
# b. Zu 1.: ``$unwind`` ist optional, da ``$group`` auch Arrays direkt aggregieren kann.<br>
# c. ``{ _id: "Mouse", totalQty: 300 }, { _id: "Laptop", totalQty: 120 }`` ist ein valider Output für Query 1.<br>
# d. Zu 2.: Die Projektion entfernt standardmäßig ``_id``, wenn man ihn nicht explizit einschließt.<br>
# e. Zu 2.: Diese Pipeline führt zu einem Fehler, da ``$items.product`` kein Array ist.<br>
# f. Zu 3.: Die Aggregation liefert Fehlermeldungen, wenn ein Kunde mehrere Orders am selben Tag hat.<br>
# g. Zu 3: Die ``$sort``-Stage ist redundant, weil ``$group`` automatisch nach Datum gruppiert.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'c'}


########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.5 c1 mit 2 Punkten
subtask5 = SubTask(task5, "c1", points = 2)

tasks_ready[subtask5.task.task][subtask5.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False


# Bitte ignorieren
subtask5.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#
# <h3>9.5 d)</h3>
#
# </div>
#
# <div class="pull-right">
#
# <h4>(2 Punkt)</h4>
#
# </div>

# %% [markdown]
# Datenmodell:
# ```json
#   {
#     "_id": ObjectId,
#     "patient": "Max Mustermann",
#     "doctor": "Dr. Erika Müller",
#     "date": ISODate("2024-04-10T09:00:00Z"),
#     "diagnosis": "Grippe",
#     "prescriptions": [
#       { "medication": "Ibuprofen", "dose": "200mg", "duration": 5 },
#       { "medication": "Vitamin C", "dose": "500mg", "duration": 10 }
#     ],
#     "followUp": true
#   }
# ```

# %% [markdown]
# <pre>
# 1.  db.appointments.aggregate([
#     { $match: { followUp: true } },
#     { $project: {
#         patient: 1,
#         totalMedDays: {
#             $sum: "$prescriptions.duration"
#         },
#         firstMedication: {
#             $arrayElemAt: ["$prescriptions.medication", 0]
#         },
#         prescriptionCount: { $size: "$prescriptions" }
#     }},
#     { $sort: { totalMedDays: -1 } }
#     ])
#
# 2.  db.appointments.aggregate([
#     { $unwind: "$prescriptions" },
#     { $group: {
#         _id: "$prescriptions.medication",
#         totalDuration: { $sum: "$prescriptions.duration" },
#         count: { $sum: 1 }
#     }},
#     { $sort: { totalDuration: -1 } }
#     ])
# </pre>

# %% [markdown]
# Multiple Choice Aufgabe:
#
# Wählen Sie **alle** zutreffenden Aussagen aus!
#
# a. Zu 1: Die Pipeline zeigt nur Arztbesuche mit geplanter Nachkontrolle.<br>
# b. Zu 1: Die Sortierung erfolgt aufsteigend nach ``totalMedDays``.<br>
# c. Zu 1.: Die Pipeline ist ungültig, weil ``$prescriptions.medication`` kein direktes Array ist.<br>
# d. Zu 2.: Die Pipeline gruppiert nach Medikamentenname (_id) und berechnet die Gesamtdauer der Verschreibungen über alle Patienten.<br>
# e. Zu 2.: Die Sortierung am Ende ist aufsteigend nach ``totalDuration``.<br>
# f. Zu 2.: Die Pipeline kann fehlschlagen, wenn das Feld ``prescriptions`` leer oder nicht vorhanden ist.<br>
# g. Zu 2.: Der Output ist ``{ "_id": "Ibuprofen", "totalDuration": "400mg", "count": 2 }``.

# %%
########################################################
# Bitte beachten Sie die Notation!
# Wenn 'a' eine korrekte Ausssage ist, so fügen sie 'a' zu result hinzu
# Beispiel result ={'a','b','c','d'}
result = set()
# IHR CODE HIER
result ={'a','d'}

########################################################
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# Aufgabe 9.5 d1 mit 2 Punkten
subtask5 = SubTask(task5, "d1", points = 2)

tasks_ready[subtask5.task.task][subtask5.subtask] = True
if result == set():
    warnings.warn(f"Bitte bearbeiten Sie die Aufgabe.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False
elif [i for i in result if type(i)!= str and len(i)!=1]:
    warnings.warn(f"Bitte überprüfen Sie Ihre Antworten, es liegt ein Fehler vor.")
    tasks_ready[subtask5.task.task][subtask5.subtask] = False


# Bitte ignorieren
subtask5.setSolution(set(result))

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# # Zusammenfassung
#
# Die folgende Codezelle erlaubt es, die Teilaufgaben 9.1, 9.2, 9.3, 9.4 und 9.5 auf syntaktische Korrektheit (z.B. falsche Assertions oder Tippfehler) zu prüfen. Bitte benutzen Sie diese Codezelle, um Ihre Abgaben zu überprüfen.Die Punktzahlangaben in dieser Codezelle dienen nur der Orientierung und geben die __maximal erreichbaren__ Punkte an, nicht die tatsächlich erreichten.

# %%
# overview
from IPython.display import display, HTML
points = 0

for t in exc.getTasks():
    display(HTML(f"<div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe '{t}':</h4></div>"))
    task=exc.getTaskByLabel(t)
    for subtaskLabel in sorted(task.getSubtasks()):
        try:
            subtask = task.getSubtaskByLabel(subtaskLabel)
        except:
            display(HTML(f"<div class='alert alert-danger'>Oops! '{t}/{subtaskLabel}' wurde nicht ordnungsgemäß ausgeführt.<br /> Überprüfen Sie die Assertions. </div>"))
            continue
        else:
            info=subtask.getTaskInfo()
            points += subtask.getPoints()
            display(HTML(f"<div class='alert alert-success'>{info}. OK (+max. {subtask.getPoints()} Punkte) </div>"))

display(HTML(f"<div class='alert alert-success'><h3>Es wurden insgesamt Teilaufgaben für max. {points}/20 Punkte gefunden.</h3></div><hr />"))
# Out:
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe '9.1':</h4></div>
# <div class='alert alert-success'>Teilaufgabe a1, 1 Punkte. OK (+max. 1 Punkte) </div>
# <div class='alert alert-success'>Teilaufgabe b1, 1 Punkte. OK (+max. 1 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe '9.2':</h4></div>
# <div class='alert alert-success'>Teilaufgabe a1, 1 Punkte. OK (+max. 1 Punkte) </div>
# <div class='alert alert-success'>Teilaufgabe b1, 1 Punkte. OK (+max. 1 Punkte) </div>
# <div class='alert alert-success'>Teilaufgabe c1, 2 Punkte. OK (+max. 2 Punkte) </div>
# <div class='alert alert-success'>Teilaufgabe d1, 2 Punkte. OK (+max. 2 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe '9.3':</h4></div>
# <div class='alert alert-success'>Teilaufgabe a1, 1 Punkte. OK (+max. 1 Punkte) </div>
# <div class='alert alert-success'>Teilaufgabe b1, 1 Punkte. OK (+max. 1 Punkte) </div>
# ...
