# %% [markdown]
# <table style="width:100%; background-color:#FFFFFF" align="left">
#  <tr>
#    <td style="text-align:left; background-color:#FFFFFF">
#        <p>Prof. Dr. Stefan Decker <br>
#         M. Slupczynski <br>
#         L. Neumann <br>
#         M. Kißgen <br>
#         T. Holzheim <br></p>
#         <p><strong>2025-05-30</strong></p>
#      </td>
#    <td style="text-align:right; background-color:#FFFFFF">
#      <div>
#        <img src="https://git.rwth-aachen.de/i5/teaching/dbis-raw/-/raw/main/dbis-logo.png" width="500"/>
#      </div>
#     </td>
#  </tr>
# </table>
# <div class="clearfix"></div>
# <center>
#     <h1>Datenbanken und Informationssysteme (SoSe 2025)</h1>
#     <h1>Übung 7 - Funktionale Abhängigkeiten, Dekompositions- und Synthesealgorithmus</h1>
# </center>
#
# <center>
#     <h4>Abgabe bis 2025-06-06 14:15 Uhr</h4>
#     <strong>Zu spät eingereichte Übungen werden nicht berücksichtigt.</strong>
# </center>

# %% [markdown]
# <div class="hidden-print"><hr />
# <h3> Wichtige Hinweise</h3>
# <ul>
# <li>Bei Nichtbeachtung dieser Hinweise wird die Abgabe mit 0 Punkten bewertet!</li>
# <li>Bitte laden Sie Ihre digitalen Lösungen mit diesem Notebook ins Moodle hoch.</li>
# <li>Bitte geben Sie Namen, Matrikelnummern auf der schriftlichen Lösung an.</li>
# </ul></div>
#
# <strong>Die Lösung zu diesem Übungsblatt wird in den Übungen am 6. Juni und 9. Juni vorgestellt. <br />
# Bitte beachten Sie auch die aktuellen Ankündigungen im Moodle-Lernraum zur Vorlesung. </strong> <br />
# <em>* bezeichnet Bonusaufgaben.</em>
# <hr />

# %% [markdown]
# <h3>Abgabegruppe</h3>
# Es ist möglich die Abgabe in Gruppen von bis zu fünf Personen zu bearbeiten. <strong>Jeder Gruppenteilnehmer muss für sich ein Notebook hochladen</strong>. Wenn Sie in einer Abgabegruppe arbeiten, dürfen die Notebooks der Gruppenteilnehmer den gleichen Inhalt aufweisen. Wenn Sie in einer Gruppe arbeiten, tragen Sie hier bitte alle Gruppenteilnehmer inklusive sich selbst ein. <strong>Eine inkonsistente Angabe von Gruppenmitgliedern bei den Teilnehmern führt im Zweifel zu 0 Punkten für alle Gruppenteilnehmer!</strong> Es ist möglich zwischen den Abgaben die Gruppen zu wechseln.

# %% [markdown]
# <h4>Gruppenteilnehmer</h4>
# <ul>
#     <li>Name Kai Johannes Seeling, Matr. Nr. 456990</li>
#     <li>Name, Matr. Nr.</li>
#     <li>Name, Matr. Nr.</li>
#     <li>Name, Matr. Nr.</li>
#     <li>Name, Matr. Nr.</li>
# </ul>

# %% [markdown]
# <div class="alert alert-info hidden-print">Die folgende Codezelle sollte zu Beginn der Bearbeitung der Übung ausgeführt werden. <br /> Am Ende sollte <b>"OK, es kann los gehen!"</b> stehen. Dies kann ein paar Minuten dauern.</div>

# %%
# install the functional dependencies library
# !python --version
# %pip install -q "dbis-exc-manager~=1.0" "dbis-functional-dependencies"
from IPython.display import display, HTML
import warnings
try:
    # import libraries
    from excmanager.Task import Exercise, Task, SubTask
    # initialize task structure
    exc = Exercise(7)
    task1 = Task(exc, "7.1")
    task2 = Task(exc, "7.2")
    task3 = Task(exc, "7.3")
    tasks_ready = {"7.1": {}, "7.2": {}, "7.3": {}}
except Exception as e:
    display(HTML(
        f"<div class='alert alert-danger'><h2>Etwas ist beim import schief gelaufen:</h1>{e}</div>"))
    raise e
else:
    display(
        HTML("<div class='alert alert-success'><h1>OK, es kann los gehen!</h1></div>"))
# Out:
# Python 3.13.2
# Note: you may need to restart the kernel to use updated packages.
# <div class='alert alert-success'><h1>OK, es kann los gehen!</h1></div>

# %% [markdown]
# <div class="pull-left">
#     <h1> Aufgabe 7.1 Funktionale Abhängigkeiten und Normalformen</h1>
# </div>
# <div class="pull-right">
#     <h3> (4 Punkte) </h3>
# </div>

# %% [markdown]
# Betrachten Sie das folgende Relationsschema:
#
# $R=\{\{A,B,C,D,E,F,G,H\},\{A\to DF, CD\to E, G\to ADH, FG\to BC, B\to G, EH \to CF, H \to D\}\}$

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.1 a)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Identifizieren Sie alle Schlüsselkandidaten von $R$. Geben Sie nur das Endergebnis an.<br>
# **Schreiben Sie die Schlüsselkandidaten mit Großbuchstaben.**

# %%
# Wenn XY ein Schlüsselkandidat ist, so fügen Sie den String 'XY' zu result hinzu.
# Fügen Sie also dann nicht 'YX' oder 'xy' zu result hinzu.
#
# result ist hier eine String-Menge bestehend aus Großbuchstaben, z.B. result = {'X','YZ'}
#
result = set()
result = {'B','G'}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask(task1, "a", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    elif not element.isupper():
        print(f"Die Menge darf nur aus Großbuchstaben bestehen")

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.1 b)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Welche der Aussagen trifft auf die Attributhüllen des oben definierten Relationsschema zu?
#
# - __a:__ Es gibt ein Attribut, dessen Attributhülle keine weitere Attribute enthält.<br>
# - __b:__ Die Attributhülle von $\{ A \}$ ist $\{A, F, D, E\}$.<br>
# - __c:__ Die Attributhülle von $\{A, E, F\}$ ist $\{A, B, C, D, E, F, G\}$. Aus diesem Grund ist $\{A, B, C, D, E, F, G\}$ voll funktional abhängig von $\{A, E, F\}$.<br>
# - __d:__ Die Attributhülle von $\{ B, E, G\}$ ist $\{A, B, C, D, E, F, G, H\}$.<br>
# - __e:__ Die Attributhülle von $\{ A, E\}$ ist $\{A, B, F, G\}$.<br>
# - __f:__ Die Attributhülle einer Attributmenge enthält immer mindestens zwei Attribute.<br>
# - __g:__ Die Attributhülle einer Attributmenge enthält immer die Attributmenge selbst.<br>
# - __h:__ Die einzige minimale Menge von Attributen mit der Attributhülle $\{A, B, C, D, E, F, G, H\}$ ist $\{B\}$.<br>

# %%
 # result ist hier eine String-Menge, z.B. result = {'a','b'}. Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
result = set()
result = {'a','d','g'}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask(task1, "b", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g","h"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g,h enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.1 c)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Welche der Aussagen über das Finden von Schlüsselkandidaten sind gültig?
#
# - __a:__ Die Menge aller Attribute ist in jedem Fall ein Schlüsselkandidat.<br>
# - __b:__ Jedes Attribut, das auf keiner linken Seite einer Abhängigkeit vorkommt, ist Teil jedes Schlüsselkandidaten.<br>
# - __c:__ Jedes Attribut, das auf keiner rechten Seite einer Abhängigkeit vorkommt, ist Teil mindestens eines Schlüsselkandidaten.<br>
# - __d:__ Zur in der Vorlesung vorgestellten Berechnung eines Schlüsselkandidaten wird dieser mit $\emptyset$ angefangen iterativ aufgebaut.<br>
# - __e:__ Es gibt für jede mögliche Menge funktionaler Abhängigkeiten über einer beliebigen Attributmenge $X^′$ einen Schlüsselkandidat, der maximal $∣X^′∣/2$ Attribute beinhaltet.<br>
# - __f:__ Es gibt für jede mögliche Menge funktionaler Abhängigkeiten über einer beliebigen Attributmenge $X^′$ maximal $∣X^′∣/2$ Schlüsselkandidaten.<br>
# - __g:__ Für die Ermittlung müssen in jedem Fall nur Abhängigkeiten betrachtet werden, bei denen auf der linken Seite nur ein Attribut steht.<br>
# - __h:__ Jeder Schlüsselkandidat ist auch ein Superschlüssel.<br>

# %%
# result ist hier eine String-Menge, z.B. result = {'a','b'}. 
# Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.

result = set()
result = {'c','h'}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask( task1, "c", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g","h"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g,h enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.1 d)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Nehmen Sie an, dass das oben definierte Relationsschema in 1NF ist. Welche der Aussagen treffen auf das Relationsschema zu?
#
# - __a:__ Das Schema ist in 1NF, aber nicht in 2NF, da die Abhängigkeit $H \to D$ die 2NF verletzt.<br>
# - __b:__ Das Schema ist in 2NF, aber nicht in 3NF, da die Abhängigkeit $FG \to BC$ die 3NF verletzt.<br>
# - __c:__ Das Schema ist in 3NF, aber nicht in BCNF, da die Abhängigkeit $B \to G$ die BCNF verletzt.<br>
# - __d:__ Das Schema ist in 2NF, weil es in 1NF ist und für jedes Attribut X auf der rechten Seite gilt: X ist Teil eines Schlüsselkandidats oder X ist nicht von einer echten Teilmenge eines Schlüsselkandidats abhängig.

# %%
# result ist hier eine String-Menge, z.B. result = {'a','b'}. 
# Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.

result = set()

# IHR CODE HIER
result = {'d'}

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask( task1, "d", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h1> Aufgabe 7.2 (Synthesealgorithmus)</h1>
# </div>
#
# <div class="pull-right">
#     <h3> (9 Punkte) </h3>
# </div>

# %% [markdown]
# Wir betrachten weiterhin das obige Relationsschema:
#
# $R=\{\{A,B,C,D,E,F,G,H\},\{A\to DF, CD\to E, G\to ADH, FG\to BC, B\to G, EH \to CF, H \to D\}\}$
#
# Wenden Sie den in der Vorlesung vorgestellten Synthesealgorithmus auf das Relationenschema $R$ an, um ein Schema in der dritten Normalform zu erstellen. **Falls in einem Schritt eine Menge von Abhängigkeiten oder Attributen überprüft werden muss, prüfen Sie sie in der Reihenfolge aus der Aufgabenstellung.**
#
# Geben Sie nur das Endergebnis an.

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 a)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Der erste Schritt des Synthesealgorithmus ist die Ermittlung der kanonischen Überdeckung. Der erste Schritt dieser ist wiederum die **Linksreduktion**.
#
# Welche der folgenden Aussagen zur **Linksreduktion** sind für dieses Beispiel richtig?
#
# - __a:__ Das Attribut $E$ kann aus der Abhängigkeit $EH \to CF$ reduziert werden.<br>
# - __b:__ Die Abhängigkeit $H \to D$ kann nicht reduziert werden.<br>
# - __c:__ Das Attribut $C$ kann aus der Abhängigkeit $CD \to E$ reduziert werden.<br>
# - __d:__ Das Attribut $F$ kann aus der Abhängigkeit $FG \to BC$ reduziert werden.<br>
# - __e:__ Die Abhängigkeit $A \to DF$ kann reduziert werden, da die Attributhülle von $DF$ nicht alle Attribute aus $A$ enthält.<br>
# - __f:__ Es kann nur eine der ursprünglichen funktionalen Abhängigkeiten reduziert werden.<br>
# - __g:__ Es können mehr als zwei der ursprünglichen funktionalen Abhängigkeiten reduziert werden.

# %%
# result ist hier eine String-Menge, z.B. result = {'a','b'}.
# Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
#
result = set()
result = {'b','d','f'}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task2, "a", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 b)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkte)</h3>
# </div>

# %% [markdown]
# Der zweite Schritt der kanonischen Überdeckung ist die **Rechtsreduktion**.
#
# Geben Sie das Ergebnis nach der **Rechtsreduktion** an. Benutzen Sie die Funktion ```add_dependency(left: String, right: String)``` der Klasse ```FunctionalDependencySet``` zum Hinzufügen von Abhängigkeiten. Benutzen Sie genau das vordefinierte FunctionalDependencySet ```result```, welches alle Attribute und entfernten Abhängigkeiten beinhalten soll.

# %%
from dbis_functional_dependencies.BCNF import FunctionalDependencySet

# Geben Sie die reduzierten Funktionalen Abhängigkeiten mithilfe eines FunctionalDependencySets an
# Zum Beispiel:
# result= FunctionalDependencySet("PQRS")
# result.add_dependency("P","S") # Entspricht P->S
# result.add_dependency("PQ","R") # Entspricht PQ->R
#
#
result = FunctionalDependencySet("ABCDEFGH")
result.add_dependency("A","DF")
result.add_dependency("CD","E")
result.add_dependency("G","AH")
result.add_dependency("G","BC")
result.add_dependency("B","G")
result.add_dependency("EH","CF")
result.add_dependency("H","D")

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task2, "b", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 c)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Damit wir die kanonische Überdeckung erhalten, müssen wir nun **leere Abhängigkeiten entfernen** und danach **Abhängigkeiten mit gleicher linker Seite zusammenfassen**.
#
# Welche der folgenden Aussagen sind für diesen Schritt richtig?
#
# - __a:__ Es gibt keine leeren rechten Seiten, die zu entfernen sind.<br>
# - __b:__ Es werden Abhängigkeiten zusammengefasst.<br>
# - __c:__ Die kanonische Überdeckung enthält die funktionale Abhängigkeit $G \to AH$.<br>
# - __d:__ Die kanonische Überdeckung enthält die funktionale Abhängigkeit $H \to \emptyset$.<br>
# - __e:__ Es werden Abhängigkeiten zusammengefasst die auf ihrer rechten Seite $A$ und $E$ beinhalten.<br>
# - __f:__ Die kanonische Überdeckung enthält die funktionale Abhängigkeit $B \to G$.<br>
# - __g:__ Die kanonische Überdeckung enthält genau 5 Abhängigkeiten.<br>
# - __h:__ Die kanonische Überdeckung enthält genau 6 Abhängigkeiten.<br>

# %%
# result ist hier eine String-Menge, z.B. result = {'a','b'}. Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
result = set()
result = {'a','b','f','h'}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task2, "c", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g","h"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g,h enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 d)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Im zweiten Schritt des Synthesealgorithmus werden neue Relationsschemata erstellt.
#
# Welche Aussagen über diesen Schritt treffen zu?
#
# - __a:__ Es wird für jede Abhängigkeit eine neue Relation erstellt.<br>
# - __b:__ Es wird für jeden Schlüsselkandidaten eine neue Relation erstellt.<br>
# - __c:__ Es wird für jedes Attribut eines Schlüsselkandidaten eine neue Relation erstellt.<br>
# - __d:__ Es wird eine neue Relation mit Attributmenge $\{C, D, E\}$ erstellt.<br>
# - __e:__ Es werden insgesamt fünf neue Relationen erstellt.<br>
# - __f:__ Es werden insgesamt mehr als sechs neue Relationen erstellt.
# - __g:__ Es gibt eine Abhängigkeit, die in mehreren Relationen enthalten ist.

# %%
 # result ist hier eine String-Menge, z.B. result = {'a','b'}. Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
result = set()
result = {'a','d','g'}
# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask(task2, "d", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 e)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Die letzten beiden Schritte des Synthesealgorithums beinhalten das Hinzufügen einer Schlüsselrelation sowie das Entfernen von Relationen, deren Attribute bereits in anderen Relationen enthalten sind.
#
# Welche Aussagen treffen auf diese Schritte zu?
#
# - __a:__ Es braucht keine Schlüsselrelation hinzugefügt werden, da die Attribute von mindestens einem der zwei Schlüsselkandidaten in mindestens einer neuen Relation enthalten sind.<br>
# - __b:__ Wir können eine neue Schlüsselrelation mit der Attributmenge $\{C, F, H\}$ hinzufügen, da $CFH$ ein Superschlüssel ist.<br>
# - __c:__ Wir erhalten zum Schluss die gleiche Anzahl an Relationen wie vor den beiden Schritten vorhanden waren.<br>
# - __d:__ Wir erhalten zum Schluss mehr Relationen als vor den beiden Schritten vorhanden waren.<br>
# - __e:__ Wir erhalten zum Schluss weniger Relationen als vor den beiden Schritten vorhanden waren.<br>
# - __f:__ Es muss eine der Relationen entfernt werden, die die Abhängigkeit $B \to G$ beinhaltet. Welche dieser Relationen entfernt wird, ist egal.<br>

# %%
 # result ist hier eine String-Menge, z.B. result = {'a','b'}. Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
result = set()
result = {'a','e'}

# IHR CODE HIER


# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 PUNKTE
subtask = SubTask(task2, "e", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.2 f)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(4 Punkte)</h3>
# </div>

# %% [markdown]
# **Geben Sie nun das Endergebnis des auf das Relationenschema R angewandten Synthesealgorithmus an.** Schreiben Sie die Attributmengen als String in den Konstruktor der unten stehenden Klassen ```FunctionalDependencySet``` und benutzen Sie die Funktion ```add_dependency(left: String, right: String)``` der Klasse zum Hinzufügen von Abhängigkeiten zu einer Attributmenge. Die richtige Lösung enthält **fünf** Relationen. Wenn Sie mehr als fünf Relationen angeben, erhalten Sie 0 Punkte.

# %%
from dbis_functional_dependencies.BCNF import FunctionalDependencySet

# Geben Sie die Mengen funktionaler Abhängigkeiten entsprechend folgendem Beispiel als Menge 
# von FunctionalDependencySet Instanzen an.
#
# Bsp für ein Ergebnis mit 2 Relationen:
# fdset1= FunctionalDependencySet("PQRS") # Entspricht einer Relation mit Attributen {P,Q,R,S}
# fdset1.add_dependency("P","S") # Entspricht P->S
# fdset1.add_dependency("PQ","R") # Entspricht PQ->R
#
# Sollte eine leere Abhängigkeit enthalten sein, dann schreiben Sie "". 
#
# fdset2= FunctionalDependencySet("WXYZ")
# fdset2.add_dependency("W","XY")
# fdset2.add_dependency("W","") # W->\emptyset
#
# result={fdset1,fdset2}
#

fdset1= FunctionalDependencySet("ADF") # Entspricht einer Relation mit Attributen {P,Q,R,S}
fdset1.add_dependency("A","DF")
fdset2= FunctionalDependencySet("CDE")
fdset2.add_dependency("CD","E")
fdset3= FunctionalDependencySet("ABCGH")
fdset3.add_dependency("G","ABCH")
fdset3.add_dependency("B","G")
fdset4= FunctionalDependencySet("CEFH")
fdset4.add_dependency("EH","CF")
fdset5= FunctionalDependencySet("DH")
fdset5.add_dependency("H","D")
result = set()
result = {fdset1,fdset2,fdset3,fdset4,fdset5}

# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task2, "f", points = 4)
tasks_ready[subtask.task.task][subtask.subtask] = True

if not len(result)==5:
    warnings.warn(f"Es müssen fünf Relationen angegeben werden.")

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
#     <h1> Aufgabe 7.3 (Dekompositionsalgorithmus) </h1>
# </div>
#
# <div class="pull-right">
#     <h3> (7 Punkte) </h3>
# </div>

# %% [markdown]
# Betrachten Sie das folgende Relationenschema:
#
# $R=\{\{A,B,C,D,E,F\},\{B\to E, EF\to AD, D\to A, AC\to DE, AB \to BD, BC\to AD, ABC\to D\}\}$

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.3 a)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(1 Punkt)</h3>
# </div>

# %% [markdown]
# Identifizieren Sie alle Schlüsselkandidaten. Geben Sie nur das Endergebnis an.<br>

# %%
# Wenn XY ein Schlüsselkandidat ist, so fügen Sie den String 'XY' zu result hinzu.
# Fügen Sie also dann nicht 'YX' zu result hinzu.
#
# result ist hier eine String-Menge, z.B. result = {'X','YZ'}
#
result = set()
result = {'BCF'}

# IHR CODE HIER
result = {'BCF'}
# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task3, "a", points = 1)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    elif not element.isupper():
        print(f"Die Menge darf nur aus Großbuchstaben bestehen.")
subtask.setSolution(result)
subtask.setData(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10 result = {'BCF'}
#      11 # DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
# ---> 12 subtask = SubTask( task3, "a", points = 1)
#      14 tasks_ready[subtask.task.task][subtask.subtask] = True
#      15 for element in result:
#
# NameError: name 'SubTask' is not defined

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.3 b)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(2 Punkte)</h3>
# </div>

# %% [markdown]
# Welche der funktionalen Abhängigkeiten aus dem Ursprungsschema verletzen die BCNF?
#
# - __a:__ $B\to E$ <br>
# - __b:__ $EF\to AD$<br>
# - __c:__ $D\to A$<br>
# - __d:__ $AC\to DE$<br>
# - __e:__ $AB \to BD$<br>
# - __f:__ $BC\to AD$<br>
# - __g:__ $ABC\to D$

# %%
# result ist hier eine String-Menge, z.B. result = {'a','b'}. Füllen Sie die Menge unter dem Kommentar mit Ihrer Lösung.
result = set()

# IHR CODE HIER
result = {'a','b','c','d','e','f','g'}

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task3, "b", points = 2)

tasks_ready[subtask.task.task][subtask.subtask] = True
for element in result:
    if not isinstance(element, str):
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur aus Strings bestehen.")
        break
    if not element in ["a","b","c","d","e","f","g"]:
        tasks_ready[subtask.task.task][subtask.subtask] = False
        warnings.warn(f"Die Menge darf nur die Antwortmöglichkeiten a,b,c,d,e,f,g enthalten.")
        break

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# <div class="pull-left">
# <h2>Aufgabe 7.3 c)</h2>
# </div>
#
# <div class="pull-right">
# <h3>(4 Punkte)</h3>
# </div>

# %% [markdown]
# Führen Sie mithilfe des in der Vorlesung vorgestellten Dekompositionsalgorithmus eine BCNF-Zerlegung durch. **Zerlegen Sie immer entlang der erstmöglichen Abhängigkeit.**
#
# Geben Sie nur das Endergebnis an. Schreiben Sie die Attributmengen als String in den Konstruktor der unten stehenden Klassen ``FunctionalDependencySet`` und benutzen Sie die Funktion ``add_dependency(left: String, right: String)`` der Klasse zum Hinzufügen von Abhängigkeiten zu einer Attributmenge. Die richtige Lösung enthält **vier** Relationen. Wenn Sie mehr als vier Relationen angeben, erhalten Sie 0 Punkte.

# %%
from dbis_functional_dependencies.BCNF import FunctionalDependencySet

# Geben Sie die Mengen funktionaler Abhängigkeiten entsprechend folgendem Beispiel als Menge 
# von FunctionalDependencySet Instanzen an.
#
# Bsp für ein Ergebnis mit 2 Relationen:
# fdset1= FunctionalDependencySet("PQRS")
# fdset1.add_dependency("P","S")
# fdset1.add_dependency("PQ","R")
#
# Sollte eine leere Abhängigkeit enthalten sein, dann schreiben Sie "". 
#
# fdset2= FunctionalDependencySet("WXYZ")
# fdset2.add_dependency("W","XY")
# fdset2.add_dependency("W","")
#
# result={fdset1,fdset2}
#

result = set()
fdset1= FunctionalDependencySet("BE")
fdset1.add_dependency("B","E")
fdset2= FunctionalDependencySet("AD")
fdset2.add_dependency("D","A")
fdset3= FunctionalDependencySet("BCD")
fdset3.add_dependency("BC","D")
fdset4= FunctionalDependencySet("BCF")
result={fdset1,fdset2,fdset3,fdset4}
# IHR CODE HIER

# DIESEN TEIL NICHT VERÄNDERN, SONST GIBT ES 0 Punkte
subtask = SubTask( task3, "c", points = 4)

tasks_ready[subtask.task.task][subtask.subtask] = True
if not len(result)==4:
    warnings.warn(f"Es müssen vier Relationen angegeben werden.")

subtask.setSolution(result)
subtask.setData(result)

# %%
# Autograder, bitte ignorieren

# %% [markdown]
# ---

# %% [markdown]
# # Zusammenfassung
#
# Die folgende Codezelle erlaubt es, die Teilaufgaben 7.1, 7.2 und 7.3 auf syntaktische Korrektheit (z.B. falsche Assertions oder Tippfehler) zu prüfen. Bitte benutzen Sie diese Codezelle, um Ihre Abgaben zu überprüfen.Die Punktzahlangaben in dieser Codezelle dienen nur der Orientierung und geben die __maximal erreichbaren__ Punkte an, nicht die tatsächlich erreichten.

# %%
# overview
tasks =["7.1","7.2","7.3"]
from IPython.display import display, HTML
points = 0

for t in tasks:
    display(HTML(f"<div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe {t}:</h4></div>"))

    task = exc.getTaskByLabel(t)
    subtasks = task.getSubtasks()
    for i in subtasks:
        display(HTML(f"<div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe {t}{subtasks[i].subtask}):</h4></div>"))
        try:
            subTaskGraph = subtasks[i].getData()
        except Exception as e:
            display(HTML(f"<div class='alert alert-danger'> Teilaufgabe {t}{subtasks[i].subtask}) wurde nicht ordnungsgemäß ausgeführt.<br /> Überprüfen Sie die Warnings. </div>"))
            continue
        else:
            if not tasks_ready[subtasks[i].task.task][subtasks[i].subtask]:
                display(HTML(f"<div class='alert alert-danger'> Teilaufgabe {t}{subtasks[i].subtask}) wurde nicht ordnungsgemäß ausgeführt.<br /> Überprüfen Sie die Warnings. </div>"))
                continue
            points += subtasks[i].getPoints()
            display(HTML(f"<div class='alert alert-success'> ... BEARBEITET (+max. {subtasks[i].getPoints()} Punkte) </div>"))

display(HTML(f"<div class='alert alert-success'><h3>Es wurden insgesamt Teilaufgaben für max. {points}/20 Punkte gefunden.</h3></div><hr />"))
# Out:
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.1:</h4></div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.1a):</h4></div>
# <div class='alert alert-success'> ... BEARBEITET (+max. 1 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.1b):</h4></div>
# <div class='alert alert-success'> ... BEARBEITET (+max. 1 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.1c):</h4></div>
# <div class='alert alert-success'> ... BEARBEITET (+max. 1 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.2:</h4></div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.2a):</h4></div>
# <div class='alert alert-success'> ... BEARBEITET (+max. 1 Punkte) </div>
# <div class='alert alert-info'><h4>Sammle Ergebnisse von Teilaufgabe 7.2b):</h4></div>
# <div class='alert alert-success'> ... BEARBEITET (+max. 1 Punkte) </div>
# ...
